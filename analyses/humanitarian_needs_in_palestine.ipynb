# %% [markdown]
# Potential questions:
#
# Funding:
# Total funding amount by time
# Funding coverage by area
#
#
# Aid:
# Required and recommended amounts compared to delivered aid
# Aid distribution patterns and gaps
# Spikes in food/commodity prices
# Aid sources, aid types and import methods
# Commodity prices against aid delivered
#
# Other:
# Top donors
# Requirement changes over time
#
#
#
# To consider:
# Funding coverage % per cluster, per year (FTS files).
# Price shock detection for basic foods inside Gaza (WFP + commodity-prices).
# Malnutrition trend vs. price trend (join on date/admin).
# Market functionality score (WFP markets) vs. incoming cargo (Gaza supplies).
# Admin-level severity ranking (HNO 2022/23) vs. actmalnutrition.itio
